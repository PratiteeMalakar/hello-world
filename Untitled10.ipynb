# %% [markdown]
# <a href="https://colab.research.google.com/github/PratiteeMalakar/hello-world/blob/main/Untitled10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# Load the CSV file
df = pd.read_csv('combined_data.csv')

# %%
pip install pinecone openai
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 244.8/244.8 kB 2.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 361.3/361.3 kB 6.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.6/75.6 kB 4.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.9/77.9 kB 3.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 318.9/318.9 kB 16.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 117.6/117.6 kB 7.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 3.8 MB/s eta 0:00:00
# ...

# %%
import pinecone

# %%
from pinecone import Pinecone
import os
from google.colab import userdata

os.environ["PINECONE_API_KEY"]=userdata.get("PINECONE")

api_key = os.getenv("PINECONE_API_KEY")

pc = Pinecone(api_key = api_key)

# %%
from pinecone import ServerlessSpec

cloud = os.environ.get('PINECONE_CLOUD') or 'aws'
region = os.environ.get('PINECONE_REGION') or 'us-east-1'

spec = ServerlessSpec(cloud=cloud , region=region)

# %%
import time
index_name = "indexci"

if index_name in pc.list_indexes().names():
    pc.delete_index(index_name)

# we create a new index
pc.create_index(
        index_name,
        dimension=1536,  # dimensionality of text-embedding-ada-002
        metric='dotproduct',
        spec=spec
    )

# wait for index to be initialized
while not pc.describe_index(index_name).status['ready']:
    time.sleep(1)

# %%
index = pc.Index(index_name)
index.describe_index_stats()
# Out:
# {'dimension': 1536,
#  'index_fullness': 0.0,
#  'namespaces': {},
#  'total_vector_count': 0}

# %%
import openai
import numpy as np

# Set up Mistral.ai API key
#mistralai.api_key = 'YOUR_MISTRALAI_API_KEY'
os.environ["OPENAI_API_KEY"]=userdata.get("OPENAI")

mistral_api_key = os.getenv("OPENAI_API_KEY")

# %%
from openai import OpenAI
client = OpenAI()

def get_embedding(text, model="text-embedding-3-small"):
   return client.embeddings.create(input = [text], model=model).data[0].embedding

# %%
def add_data_to_index(text_data, doc_id):
    # Generate embeddings for the given text data

    embeddings = get_embedding(text_data)

    # Upsert the data to Pinecone index
    index.upsert([
        {
            'id': f'doc_{doc_id}',
            'values': embeddings,
            'metadata': {'text': text_data}
        }
    ])

    return embeddings

# %%
from langchain.text_splitter import RecursiveCharacterTextSplitter

text_splitter = RecursiveCharacterTextSplitter(
    chunk_size=500,  # Customize the chunk size as needed
    chunk_overlap=20  # Optional: Overlap between chunks for better context retention
)

for idx, column in enumerate(df.columns):
    # Combine the column data into a single string
    column_text = ' '.join(df[column].astype(str).tolist())

    # Split the combined text into smaller chunks
    chunks = text_splitter.split_text(column_text)

    # Add each chunk to Pinecone
    for chunk_idx, chunk in enumerate(chunks):
        chunk_doc_id = f"{idx}_{chunk_idx}"
        add_data_to_index(chunk, chunk_doc_id)

# %%
from transformers import AutoTokenizer, AutoModel
import torch

# Load pre-trained model and tokenizer
tokenizer = AutoTokenizer.from_pretrained('sentence-transformers/all-MiniLM-L6-v2')
model = AutoModel.from_pretrained('sentence-transformers/all-MiniLM-L6-v2')

# Function to generate embeddings
def generate_embeddings(text):
    inputs = tokenizer(text, return_tensors='pt', truncation=True, padding=True, max_length=512)
    with torch.no_grad():
        outputs = model(**inputs)
    embeddings = outputs.last_hidden_state.mean(dim=1)
    return embeddings.squeeze().numpy()
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/350 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/612 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/90.9M [00:00<?, ?B/s]

# %%
# Function to retrieve similar documents
def retrieve_similar_docs(query, k=5):
    query_embedding = generate_embeddings(query)
    response = index.query(vector=query_embedding, top_k=k)
    return response['matches']

# %%
def generate_response(query):
    # Query the Pinecone index for similar documents
    response = index.query(vector=get_embedding(query), top_k=5, include_metadata=True)
    similar_docs = response['matches']

    # Check if any similar documents were found
    if similar_docs:
        # Handle potential missing metadata
        context = ' '.join([doc['metadata'].get('text', '') if 'metadata' in doc else '' for doc in similar_docs])
        input_text = f"Context: {context}\n\nQuestion: {query}\n\nAnswer:"

        # Generate a response using Groq AI's chat completion
        chat_completion = client.chat.completions.create(
            messages=[
                {
                    "role": "user",
                    "content":"What is Ulta Beauty?" ,
                }
            ],
            model="llama3-8b-8192",  # Replace with the correct model identifier from Groq AI
        )

        return chat_completion.choices[0].message.content
    else:
        return "No similar documents found. Please try a different query."

# %%
response_text = generate_response(query)
# Out:
# ---------------------------------------------------------------------------
# NotFoundError                             Traceback (most recent call last)
# <ipython-input-53-1760b3e46009> in <cell line: 1>()
# ----> 1 response_text = generate_response(query)
#
# <ipython-input-52-e673074c4acb> in generate_response(query)
#       1 def generate_response(query):
#       2     # Query the Pinecone index for similar documents
# ----> 3     response = index.query(vector=get_embedding(query), top_k=5, include_metadata=True)
#       4     similar_docs = response['matches']
#       5
#
# <ipython-input-16-f86f24f0c9a1> in get_embedding(text, model)
#       3
#       4 def get_embedding(text, model="text-embedding-3-small"):
# ----> 5    return client.embeddings.create(input = [text], model=model).data[0].embedding
#
# /usr/local/lib/python3.10/dist-packages/groq/resources/embeddings.py in create(self, input, model, encoding_format, user, extra_headers, extra_query, extra_body, timeout)
# ...

# %%
query = "What is Ulta Beauty?"
response = index.query(vector=generate_embeddings(query), top_k=5, include_metadata=True)
#print("Similar documents found:", response['matches'])

response_text = generate_response(query)
print(response_text)
# Out:
# ---------------------------------------------------------------------------
# PineconeApiValueError                     Traceback (most recent call last)
# <ipython-input-49-c990d810702c> in <cell line: 2>()
#       1 query = "What is Ulta Beauty?"
# ----> 2 response = index.query(vector=generate_embeddings(query), top_k=5, include_metadata=True)
#       3 #print("Similar documents found:", response['matches'])
#       4
#       5 response_text = generate_response(query)
#
# /usr/local/lib/python3.10/dist-packages/pinecone/utils/error_handling.py in inner_func(*args, **kwargs)
#       9     def inner_func(*args, **kwargs):
#      10         try:
# ---> 11             return func(*args, **kwargs)
#      12         except MaxRetryError as e:
#      13             if isinstance(e.reason, ProtocolError):
#
# /usr/local/lib/python3.10/dist-packages/pinecone/data/index.py in query(self, top_k, vector, id, namespace, filter, include_values, include_metadata, sparse_vector, *args, **kwargs)
# ...

# %%
pip install groq
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 103.5/103.5 kB 957.8 kB/s eta 0:00:00
# ...

# %%
import os

from groq import Groq

os.environ["GROQ_API_KEY"]=userdata.get("GROQ")

client = Groq(
    api_key=os.environ.get("GROQ_API_KEY"),
)

chat_completion = client.chat.completions.create(
    messages=[
        {
            "role": "user",
            "content": "Explain the importance of fast language models",
        }
    ],
    model="llama3-8b-8192",
)

print(chat_completion.choices[0].message.content)
# Out:
# Fast language models have gained significant attention in the field of natural language processing (NLP) in recent years due to their ability to process and understand human language quickly and efficiently. Here are some key reasons why fast language models are important:
#
# 1. **Speed and Scalability**: Fast language models can process large volumes of text data quickly and efficiently, enabling applications such as text classification, sentiment analysis, and machine translation at scale. This is particularly important for applications that require real-time processing, such as chatbots, customer service, and social media monitoring.
# 2. **Improved Accuracy**: Fast language models can be trained on large amounts of data, which can lead to improved accuracy and better performance on a wide range of NLP tasks. This is because they can process and analyze more data in a shorter amount of time, reducing the risk of overfitting and improving generalization.
# ...

# %%
pip install langchain
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 997.8/997.8 kB 4.6 MB/s eta 0:00:00
# ...

# %%
from langchain_pinecone import PineconeVectorStore
from langchain_openai import OpenAIEmbeddings

embeddings = OpenAIEmbeddings()
vectorstore = PineconeVectorStore(index_name=index_name, embedding=embeddings)

# %%
pip install langchain_pinecone langchain_openai
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.4/50.4 kB 789.0 kB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.8/49.8 kB 2.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 384.8/384.8 kB 3.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 14.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 140.4/140.4 kB 8.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 141.9/141.9 kB 8.7 MB/s eta 0:00:00
# ...
#   Attempting uninstall: tenacity
#     Found existing installation: tenacity 9.0.0
#     Uninstalling tenacity-9.0.0:
#       Successfully uninstalled tenacity-9.0.0
# ...

# %%
from langchain.schema import Document
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-27-55372ad8d5d0> in <cell line: 1>()
# ----> 1 from langchain.schema import Document
#
# ModuleNotFoundError: No module named 'langchain'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
pip install langchain.schema
# Out:
# ERROR: Could not find a version that satisfies the requirement langchain.schema (from versions: none)
# ERROR: No matching distribution found for langchain.schema

# %%
for column_name in df.columns:
    # Extract the column as a list of strings
    texts = df[column_name].astype(str).tolist()

    # Convert the strings to Document objects
    documents = [Document(page_content=text) for text in texts]

    # Create the Pinecone vector store from the documents
    vectorstore = PineconeVectorStore.from_documents(
        documents,
        index_name=index_name,
        embedding=embeddings
    )
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-26-b0fc1526b6ef> in <cell line: 1>()
#       4
#       5     # Convert the strings to Document objects
# ----> 6     documents = [Document(page_content=text) for text in texts]
#       7
#       8     # Create the Pinecone vector store from the documents
#
# <ipython-input-26-b0fc1526b6ef> in <listcomp>(.0)
#       4
#       5     # Convert the strings to Document objects
# ----> 6     documents = [Document(page_content=text) for text in texts]
#       7
#       8     # Create the Pinecone vector store from the documents
#
# NameError: name 'Document' is not defined
